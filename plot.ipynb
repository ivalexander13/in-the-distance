# %%
# %load_ext autoreload
# %autoreload 2

# %%
from src.plot_stressor_regimes import plot_stressor_regimes
plot_stressor_regimes()
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-3-6db76d0eb06c> in <module>
#       1 from src.plot_stressor_regimes import plot_stressor_regimes
# ----> 2 plot_stressor_regimes()
#
# /data/yosef2/users/ivalexander13/ivan-cassiopeia-benchmarking/src/plot_stressor_regimes.py in plot_stressor_regimes(topology_type, numcells, fitness_regimes, stressors, numchars__default, numstates__default, mut_prop__default, drop_total__default, random_seeds, solver_names, solver_plot_params, plot_params)
#     306                             lt_parameters = lt_parameters,
#     307                             solver_parameters = solver_parameters,
# --> 308                         )
#     309                     ]
#     310                 )
#
# /data/yosef2/users/ivalexander13/ivan-cassiopeia-benchmarking/src/caching.py in r_res_res(*args, **kwargs)
# ...
