# %%
# %load_ext autoreload
# %autoreload 2

# %%
from src.plotter import plot_stressor_regimes
plot_stressor_regimes()
# Out:
# nj > no_fit > tree0 > char20:   0%|          | 2/6000 [02:19<116:19:04, 69.81s/it]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-46-23ccebc458bd> in <module>
#       1 from src.plotter import plot_stressor_regimes
# ----> 2 plot_stressor_regimes()
#
# /data/yosef2/users/ivalexander13/ivan-cassiopeia-benchmarking/src/caching.py in r_res_res(*args, **kwargs)
#      91             cache_dir = get_cache_dir()
#      92             if cache_dir is None:
# ---> 93                 return func(*args, **kwargs)
#      94
#      95             use_hash = get_use_hash()
#
# /data/yosef2/users/ivalexander13/ivan-cassiopeia-benchmarking/src/plotter.py in plot_stressor_regimes(topology_type, numcells, fitness_regimes, stressors, numchars__default, numstates__default, mut_prop__default, drop_total__default, random_seeds, solver_names, solver_plot_params, plot_params)
# ...
