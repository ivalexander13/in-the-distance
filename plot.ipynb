# %%
# %load_ext autoreload
# %autoreload 2

# %%
from src.plot_stressor_regimes import plot_stressor_regimes
plot_stressor_regimes(
    random_seeds = range(50),
    stressors={
        "numchars": [10],
        "numstates": [5],
        "mut_prop": [0.1],
        "drop_total": [0],
    },
)
# Out:
# nj_iwhd_oracle > high_fit > tree49 > drop_total0: 100%|█████████▉| 1199/1200 [00:01<00:00, 638.42it/s]
# nj_iwhd_oracle > high_fit > tree49 > drop_total0: 100%|██████████| 1200/1200 [00:10<00:00, 116.99it/s]
# ['./plots/rf_benchmark.high_fit.png',
#  './plots/rf_benchmark.no_fit.png',
#  './plots/triplets_benchmark.high_fit.png',
#  './plots/triplets_benchmark.no_fit.png']
